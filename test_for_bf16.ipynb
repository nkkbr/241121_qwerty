# %%
from qwerty_qwen2 import QwertyQwen2ForCausalLM
import torch

model = QwertyQwen2ForCausalLM.from_pretrained(
    "/data/uchiha_ssd2/fengqi/241121_qwerty/231124_012656/checkpoint-4651",
    torch_dtype=torch.bfloat16,
    device_map = "cuda:0",
    )
# Out:
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.embeddings.class_embedding: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.embeddings.patch_embedding.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.embeddings.position_embedding.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.pre_layrnorm.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.pre_layrnorm.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.0.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.1.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.2.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.3.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.4.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.5.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.6.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.6.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.6.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# ...
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.22.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.k_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.k_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.v_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.v_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.q_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.q_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.out_proj.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.self_attn.out_proj.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.layer_norm1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.layer_norm1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.mlp.fc1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.mlp.fc1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.mlp.fc2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.mlp.fc2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.layer_norm2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.encoder.layers.23.layer_norm2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.post_layernorm.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# /data/satori_hdd4/fengqi/anaconda3/envs/base_3_12/lib/python3.12/site-packages/torch/nn/modules/module.py:2400: UserWarning: for vision_model.post_layernorm.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
for name, param in model.named_parameters():
    print(name)
    print(f"          {param.dtype}")
# Out:
# model.embed_tokens.weight
#           torch.bfloat16
# model.layers.0.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.0.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.0.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.0.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.0.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.0.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.0.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.0.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.0.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.0.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.0.input_layernorm.weight
#           torch.bfloat16
# model.layers.0.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.1.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.1.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.1.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.1.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.1.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.1.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.1.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.1.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.1.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.1.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.1.input_layernorm.weight
#           torch.bfloat16
# model.layers.1.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.2.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.2.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.2.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.2.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.2.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.2.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.2.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.2.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.2.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.2.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.2.input_layernorm.weight
#           torch.bfloat16
# model.layers.2.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.3.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.3.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.3.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.3.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.3.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.3.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.3.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.3.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.3.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.3.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.3.input_layernorm.weight
#           torch.bfloat16
# model.layers.3.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.4.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.4.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.4.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.4.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.4.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.4.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.4.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.4.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.4.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.4.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.4.input_layernorm.weight
#           torch.bfloat16
# model.layers.4.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.5.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.5.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.5.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.5.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.5.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.5.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.5.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.5.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.5.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.5.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.5.input_layernorm.weight
#           torch.bfloat16
# model.layers.5.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.6.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.6.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.6.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.6.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.6.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.6.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.6.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.6.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.6.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.6.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.6.input_layernorm.weight
#           torch.bfloat16
# model.layers.6.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.7.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.7.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.7.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.7.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.7.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.7.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.7.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.7.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.7.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.7.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.7.input_layernorm.weight
#           torch.bfloat16
# model.layers.7.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.8.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.8.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.8.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.8.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.8.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.8.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.8.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.8.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.8.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.8.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.8.input_layernorm.weight
#           torch.bfloat16
# model.layers.8.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.9.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.9.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.9.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.9.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.9.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.9.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.9.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.9.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.9.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.9.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.9.input_layernorm.weight
#           torch.bfloat16
# model.layers.9.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.10.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.10.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.10.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.10.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.10.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.10.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.10.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.10.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.10.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.10.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.10.input_layernorm.weight
#           torch.bfloat16
# model.layers.10.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.11.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.11.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.11.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.11.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.11.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.11.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.11.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.11.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.11.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.11.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.11.input_layernorm.weight
#           torch.bfloat16
# model.layers.11.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.12.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.12.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.12.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.12.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.12.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.12.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.12.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.12.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.12.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.12.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.12.input_layernorm.weight
#           torch.bfloat16
# model.layers.12.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.13.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.13.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.13.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.13.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.13.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.13.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.13.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.13.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.13.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.13.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.13.input_layernorm.weight
#           torch.bfloat16
# model.layers.13.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.14.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.14.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.14.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.14.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.14.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.14.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.14.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.14.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.14.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.14.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.14.input_layernorm.weight
#           torch.bfloat16
# model.layers.14.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.15.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.15.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.15.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.15.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.15.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.15.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.15.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.15.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.15.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.15.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.15.input_layernorm.weight
#           torch.bfloat16
# model.layers.15.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.16.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.16.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.16.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.16.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.16.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.16.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.16.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.16.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.16.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.16.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.16.input_layernorm.weight
#           torch.bfloat16
# model.layers.16.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.17.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.17.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.17.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.17.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.17.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.17.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.17.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.17.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.17.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.17.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.17.input_layernorm.weight
#           torch.bfloat16
# model.layers.17.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.18.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.18.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.18.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.18.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.18.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.18.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.18.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.18.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.18.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.18.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.18.input_layernorm.weight
#           torch.bfloat16
# model.layers.18.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.19.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.19.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.19.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.19.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.19.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.19.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.19.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.19.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.19.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.19.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.19.input_layernorm.weight
#           torch.bfloat16
# model.layers.19.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.20.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.20.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.20.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.20.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.20.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.20.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.20.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.20.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.20.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.20.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.20.input_layernorm.weight
#           torch.bfloat16
# model.layers.20.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.21.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.21.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.21.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.21.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.21.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.21.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.21.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.21.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.21.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.21.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.21.input_layernorm.weight
#           torch.bfloat16
# model.layers.21.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.22.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.22.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.22.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.22.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.22.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.22.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.22.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.22.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.22.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.22.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.22.input_layernorm.weight
#           torch.bfloat16
# model.layers.22.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.23.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.23.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.23.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.23.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.23.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.23.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.23.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.23.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.23.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.23.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.23.input_layernorm.weight
#           torch.bfloat16
# model.layers.23.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.24.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.24.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.24.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.24.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.24.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.24.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.24.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.24.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.24.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.24.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.24.input_layernorm.weight
#           torch.bfloat16
# model.layers.24.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.25.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.25.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.25.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.25.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.25.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.25.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.25.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.25.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.25.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.25.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.25.input_layernorm.weight
#           torch.bfloat16
# model.layers.25.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.26.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.26.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.26.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.26.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.26.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.26.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.26.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.26.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.26.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.26.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.26.input_layernorm.weight
#           torch.bfloat16
# model.layers.26.post_attention_layernorm.weight
#           torch.bfloat16
# model.layers.27.self_attn.q_proj.weight
#           torch.bfloat16
# model.layers.27.self_attn.q_proj.bias
#           torch.bfloat16
# model.layers.27.self_attn.k_proj.weight
#           torch.bfloat16
# model.layers.27.self_attn.k_proj.bias
#           torch.bfloat16
# model.layers.27.self_attn.v_proj.weight
#           torch.bfloat16
# model.layers.27.self_attn.v_proj.bias
#           torch.bfloat16
# model.layers.27.self_attn.o_proj.weight
#           torch.bfloat16
# model.layers.27.mlp.gate_proj.weight
#           torch.bfloat16
# model.layers.27.mlp.up_proj.weight
#           torch.bfloat16
# model.layers.27.mlp.down_proj.weight
#           torch.bfloat16
# model.layers.27.input_layernorm.weight
#           torch.bfloat16
# model.layers.27.post_attention_layernorm.weight
#           torch.bfloat16
# model.norm.weight
#           torch.bfloat16
# model.vision_model.vision_model.embeddings.class_embedding
#           torch.bfloat16
# model.vision_model.vision_model.embeddings.patch_embedding.weight
#           torch.bfloat16
# model.vision_model.vision_model.embeddings.position_embedding.weight
#           torch.bfloat16
# model.vision_model.vision_model.pre_layrnorm.weight
#           torch.bfloat16
# model.vision_model.vision_model.pre_layrnorm.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.0.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.1.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.2.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.3.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.4.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.5.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.6.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.7.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.8.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.9.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.10.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.11.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.12.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.13.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.14.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.15.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.16.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.17.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.18.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.19.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.20.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.21.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.22.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.layer_norm1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.layer_norm1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.mlp.fc1.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.mlp.fc1.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.mlp.fc2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.mlp.fc2.bias
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.layer_norm2.weight
#           torch.bfloat16
# model.vision_model.vision_model.encoder.layers.23.layer_norm2.bias
#           torch.bfloat16
# model.vision_model.vision_model.post_layernorm.weight
#           torch.bfloat16
# model.vision_model.vision_model.post_layernorm.bias
#           torch.bfloat16
# model.mm_projector.0.weight
#           torch.bfloat16
# model.mm_projector.0.bias
#           torch.bfloat16
# model.mm_projector.2.weight
#           torch.bfloat16
# model.mm_projector.2.bias
#           torch.bfloat16
# lm_head.weight
#           torch.bfloat16
