# %% [markdown]
# # liuhaotian/LLaVA-CC3M-Pretrain-595K

# %%
import json
with open("/data/uchiha_ssd2/fengqi/llava_dataset/CC3M_Pretrain_595K/chat.json" ,'r') as f:
    dataset1 = json.load(f)

# %%
len(dataset1)
# Out:
# 595375

# %%
cur_data = dataset1[1000]
cur_data
# Out:
# {'id': 'GCC_train_002605796',
#  'image': 'GCC_train_002605796.jpg',
#  'conversations': [{'from': 'human',
#    'value': 'Give a short and clear explanation of the subsequent image.\n'},
#   {'from': 'gpt',
#    'value': 'building is getting a lot of interest lately by developers looking to open a bar or restaurant .'}]}

# %%
from PIL import Image
import os
image_folder: str = "/data/uchiha_ssd2/fengqi/llava_dataset/CC3M_Pretrain_595K/images/"
image = Image.open(os.path.join(image_folder,cur_data['image']))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
cur_data = dataset1[10000]
cur_data
# Out:
# {'id': 'GCC_train_001919424',
#  'image': 'GCC_train_001919424.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nShare a concise interpretation of the image provided.'},
#   {'from': 'gpt', 'value': 'mother and daughter carrying a bag of groceries'}]}

# %%
image = Image.open(os.path.join(image_folder,cur_data['image']))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
cur_data = dataset1[100000]
cur_data
# Out:
# {'id': 'GCC_train_001946053',
#  'image': 'GCC_train_001946053.jpg',
#  'conversations': [{'from': 'human',
#    'value': 'Describe the image concisely.\n'},
#   {'from': 'gpt', 'value': 'photo of bald eagle perched on a branch'}]}

# %%
image = Image.open(os.path.join(image_folder,cur_data['image']))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %% [markdown]
# # liuhaotian/LLaVA-Instruct-150K

# %%
with open("/data/uchiha_ssd2/fengqi/llava_dataset/COCO/llava_instruct_150k.json"  ,'r') as f:
    dataset2 = json.load(f)

# %%
len(dataset2)
# Out:
# 157712

# %% [markdown]
# # Conversation

# %%
cur_data = dataset2[100]
cur_data
# Out:
# {'id': '000000392035',
#  'image': '000000392035.jpg',
#  'conversations': [{'from': 'human',
#    'value': 'What is the man doing in the image?\n'},
#   {'from': 'gpt',
#    'value': 'The man is sitting in a chair, possibly at his computer, with a bird (a parrot) on his shoulder.'},
#   {'from': 'human',
#    'value': 'Is there any other animal present in the image?'},
#   {'from': 'gpt',
#    'value': 'Yes, there is a cat in the image, which the man is petting while sitting at his computer.'},
#   {'from': 'human', 'value': "What type of bird is on the man's shoulder?"},
#   {'from': 'gpt', 'value': "The bird on the man's shoulder is a parrot."},
#   {'from': 'human', 'value': 'Where is the parrot positioned on the man?'},
#   {'from': 'gpt',
#    'value': "The parrot is positioned on the man's shoulder, keeping its balance as the man sits and interacts with his cat."},
#   {'from': 'human',
# ...

# %%
from PIL import Image
import os
image_folder: str = "/data/uchiha_ssd2/fengqi/llava_dataset/COCO/train2017"
image = Image.open(os.path.join(image_folder,cur_data['image']))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334>

# %% [markdown]
# # detailed description

# %%
cur_data = dataset2[39]
cur_data
# Out:
# {'id': '000000562394',
#  'image': '000000562394.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat are the main appliances and features evident in the kitchen?'},
#   {'from': 'gpt',
#    'value': 'The main appliances and features visible in the kitchen include a refrigerator, microwave, sink, two small counters, a rolling cart, and a pot rack on the wall. There are also some cabinets for storage purposes.'}]}

# %%
image_folder: str = "/data/uchiha_ssd2/fengqi/llava_dataset/COCO/train2017"
image = Image.open(os.path.join(image_folder,cur_data['image']))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500>

# %% [markdown]
# # complex reasoning

# %%
cur_data = dataset2[80934]
cur_data
# Out:
# {'id': '000000058951',
#  'image': '000000058951.jpg',
#  'conversations': [{'from': 'human',
#    'value': 'What are the potential challenges in maintaining a kitchen like this?\n'},
#   {'from': 'gpt',
#    'value': "In a kitchen like this one, with a silver oven, white cabinets, and multiple cabinets and drawers, maintaining cleanliness and organization can be challenging. The oven's shiny surface and white cabinets may show dirt, dust, and smudges easily, requiring frequent cleaning to maintain their pristine appearance. Furthermore, due to the numerous cabinets and drawers, it might be challenging to optimize storage and effectively organize kitchen tools and items. Proper space usage and organization can be highly important to maintain efficiency and avoid clutter in a well-equipped kitchen like this one."}]}

# %%
image_folder: str = "/data/uchiha_ssd2/fengqi/llava_dataset/COCO/train2017"
image = Image.open(os.path.join(image_folder,cur_data['image']))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640>

# %%
cur_data = dataset2[81010]
cur_data
# Out:
# {'id': '000000084341',
#  'image': '000000084341.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat challenges might the skateboarder face during this performance?'},
#   {'from': 'gpt',
# ...

# %%
image_folder: str = "/data/uchiha_ssd2/fengqi/llava_dataset/COCO/train2017"
image = Image.open(os.path.join(image_folder,cur_data['image']))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=544x640>
